# %% [markdown]
# ## k-means clustering to analyze housing data

# %%
import pandas as pd
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
type(housing)
# Out:
# pandas.core.frame.DataFrame

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
print(housing.describe())
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
housing.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
housing['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %%
table1=housing[['longitude', 'latitude']]
table1.head()
# Out:
#    longitude  latitude
# 0    -122.23     37.88
# 1    -122.22     37.86
# 2    -122.24     37.85
# 3    -122.25     37.85
# 4    -122.25     37.85

# %%
type(table1)
# Out:
# pandas.core.frame.DataFrame

# %%
table1=table1.values
type(table1)
# Out:
# numpy.ndarray

# %%
table1.shape
# Out:
# (20640, 2)

# %%
i=1; j=0
table1[i,j]
# Out:
# -122.22

# %%
table1[0,:]
# Out:
# array([-122.23,   37.88])

# %%
table1[:,0]
# Out:
# array([-122.23, -122.22, -122.24, ..., -121.22, -121.32, -121.24])

# %% [markdown]
# For more information about numpy array, see the lecture notes

# %%
# show the histograms: one histogram corresponds to one column
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(11,8))
plt.show()

# %%
# show the histogram of a column
housing["median_income"].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### visualize the data points using pandas buil-in funciton plot

# %%
# each dot represents an area
# the color of a dot shows the median_income in that area
# the size of a dot shows the population in that area
housing.plot(kind="scatter", x="longitude", y="latitude",
    s=housing['population']/100, 
    label="population",
    c="median_income", cmap=plt.get_cmap("jet"),
    colorbar=True, alpha=0.4, figsize=(10,7),
)
plt.legend()

# %% [markdown]
# ### visualize the data points on the map of california using matplotlib

# %%
# the map is an image,'california.png'
# we need the function imread from the module io of the package skimage
from skimage.io import imread
#load the map
california_img=imread('california.png')
#show the map
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
# show the data points
# set the size of the dots by s=1
# set the color of the dots by color = 'b' - blue
# make the dots to be somewhat transparent by alpha=0.4
plt.scatter(x=housing['longitude'], y=housing['latitude'], 
            color='b',  marker='.', s=1, alpha=0.4)
# add labels to x-axis and y-axis and set fontsize
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)
# Out:
# Text(0.5, 0, 'Longitude')

# %% [markdown]
# #### Handle the categorical variable "ocean_proximity"
# Many machine learning algorithms only accept numerical data (numbers) not categorical data (category names). Thus, we need to convert categorical data into numerical data. <br>
# In our table, we have a categorical variable "ocean_proximity". We apply one-hot encoding method (https://en.wikipedia.org/wiki/One-hot) to use numbers to represent different "ocean_proximity", which can be easily done by Pandas.

# %%
housing=pd.get_dummies(housing)
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                      True                       False
# 1                      True                       False
# 2                      True                       False
# 3                      True                       False
# 4                      True                       False

# %% [markdown]
# In the new "housing" table, we see five new columns <br>
# (1) ocean_proximity_<1H OCEAN <br>
# (2) ocean_proximity_INLAND <br>
# (3) ocean_proximity_ISLAND <br>
# (4) ocean_proximity_NEAR BAY <br>
# (5) ocean_proximity_NEAR OCEAN <br>
# These columns are filled with 1s and 0s by the one-hot encoding method. <br>
# If 'ocean_proximity' is 'NEAR BAY' in the original table, then in the new table, 'ocean_proximity_NEAR BAY' is 1 and the other variables are 0s.

# %% [markdown]
# ## Next Steps
# 1. cluster the data points based on locations to find out spatial clusters
# 2. cluster the data points to find out where high/low income people live
# 3. run k-means several times for sub-task-2 to see if the result is stable or not (do not fix random_state).

# %% [markdown]
# ### 1. cluster the data points based on locations
# location features: longitude, latitude, ocean_proximity <br>
# may need to covert pandas DataFrame to numpy array <br>
# may need to normalize the features (e.g. MinMaxScaler in sk-learn)

# %%
# get a new table by selecting columns related to location
data1 = housing[['longitude', 'latitude', 'ocean_proximity_<1H OCEAN',
                 'ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY', 
                 'ocean_proximity_NEAR OCEAN' ]]
data1.head()
# Out:
#    longitude  latitude  ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 0    -122.23     37.88                      False                   False
# 1    -122.22     37.86                      False                   False
# 2    -122.24     37.85                      False                   False
# 3    -122.25     37.85                      False                   False
# 4    -122.25     37.85                      False                   False
#
#    ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                      True
# 1                   False                      True
# 2                   False                      True
# 3                   False                      True
# 4                   False                      True
#
#    ocean_proximity_NEAR OCEAN
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
# type of data1 is DataFrame
# convert DataFrame to numpy array
data1=data1.values
type(data1)
# Out:
# numpy.ndarray

# %%
# normalize data1 using MinMaxScaler in sk-learn
# data1n is the name of the normalized data1 
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

data1n = min_max_scaler.fit_transform(data1)

# %%
data1n.shape
# Out:
# (20640, 7)

# %%
# run k-means on data1n
# set n_clusters to 3
# the cluster labels are stored in the array label1
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)
kmeans.fit(data1n)

label1 = kmeans.predict(data1n)
print(label1)
label1.shape
# Out:
# [1 1 1 ... 1 1 1]
# (20640,)

# %%
# show the clusters using different colors
# choose a color in ['r', 'g', 'b', 'm', 'c', 'y']
# code to get the data points in cluster-k

color=['r', 'g', 'b', 'm', 'c', 'y']
fig, ax = plt.subplots(1,3, figsize=(10,6))
for k in range(0, 3):
    ax[k].imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
    ax[k].scatter(x=data1[label1==k,0], y=data1[label1==k,1], 
                  color=color[k],  marker='.', s=1, alpha=0.4)
    ax[k].set_ylabel("Latitude", fontsize=14)
    ax[k].set_xlabel("Longitude", fontsize=14)

# %%
# plot the histogram of cluster labels in label1
fig, ax = plt.subplots()
ax.hist(label1);

# %%
plt.hist(label1)
# Out:
# (array([9136.,    0.,    0.,    0.,    0., 8846.,    0.,    0.,    0.,
#         2658.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2. cluster data to find out where high/low income people live
# think about which columns of housing are needed for this sub-task <br>
# use at lease two features <br>
# use features related to income and location

# %%
# select some columns from housing
# assume the name of the new table is data2
data2 = housing[['longitude', 'latitude','median_income', 'ocean_proximity_<1H OCEAN',
                 'ocean_proximity_INLAND', 'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY', 
                 'ocean_proximity_NEAR OCEAN' ]]
data2.head()
# Out:
#    longitude  latitude  median_income  ocean_proximity_<1H OCEAN  \
# 0    -122.23     37.88         8.3252                      False
# 1    -122.22     37.86         8.3014                      False
# 2    -122.24     37.85         7.2574                      False
# 3    -122.25     37.85         5.6431                      False
# 4    -122.25     37.85         3.8462                      False
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# 1                   False                   False                      True
# 2                   False                   False                      True
# 3                   False                   False                      True
# 4                   False                   False                      True
#
#    ocean_proximity_NEAR OCEAN
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
# type of data2 is DataFrame
# convert DataFrame to numpy array
data2=data2.values
type(data2)
# Out:
# numpy.ndarray

# %%
# normalize data2 using MinMaxScaler
# assume that data2n is the name of the normlaized data2
# data2 >MinMaxScaler-> data2n
data2n = min_max_scaler.fit_transform(data1)

# %%
# run k-means on data2n to get cluster labels
# try to set n_clusters to 6
# the cluster labels are stored in the array label2
kmeans = KMeans(n_clusters=6)
kmeans.fit(data2n)

label2 = kmeans.predict(data2n)
print(label2)
# Out:
# [4 4 4 ... 5 5 5]

# %%
# show the clusters using different colors

color=['r', 'g', 'b', 'm', 'c', 'y']
fig, ax = plt.subplots(1,6, figsize=(10,6))
for k in range(0, 6):
   ax[k].imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)
   ax[k].scatter(x=data2[label2==k,0], y=data2[label2==k,1], 
                 color=color[k],  marker='.', s=1, alpha=0.4)
   ax[k].set_ylabel("Latitude", fontsize=8)
   ax[k].set_xlabel("Longitude", fontsize=8)

# %%
# plot the histogram of cluster labels
plt.hist(label2)
# Out:
# (array([1591.,    0., 2589.,    0., 2658.,    0., 7550.,    0., 2290.,
#         3962.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
# compute the average value of 'median_income' in each cluster
# print out the average values
mhv=housing['median_income'].values
# can use the centers from k-means
for k in np.unique(label2):
    mhv_k = mhv[label2 == k]  
    mhv_k_mean = mhv_k.mean()  
    print(f"Cluster {k}: Average median income = {mhv_k_mean}")
# Out:
# Cluster 0: Average median income = 4.619210936517914
# Cluster 1: Average median income = 3.3268121668597916
# Cluster 2: Average median income = 4.0057848006019565
# Cluster 3: Average median income = 4.147823509933775
# Cluster 4: Average median income = 4.172884759825328
# Cluster 5: Average median income = 3.1320087329631496

# %%
# show the histograms of 'median_income' in each cluster
color=['r', 'g', 'b', 'm', 'c', 'y']
fig, ax = plt.subplots(1,6, figsize=(10,2))
for k in range(0, 6):    
     ax[k].hist(x=data2[label2==k,2], color=color[k], bins=10)
     ax[k].set_xlim(0, 15)

# %% [markdown]
# we can clearly see some clusters of high-income people

# %%
# show the histogram of 'median_house_value' in each cluster
# may need to use housing to get median_house_value
color=['r', 'g', 'b', 'm', 'c', 'y']
mhv=housing['median_house_value'].values
# then you can use the sample code in the above cell
fig, ax = plt.subplots(1,6, figsize=(10,2))
for k in range(0, 6):
    mhv_k = mhv[label2 == k]
    ax[k].hist(x=mhv_k, color=color[k], bins=10)

# %% [markdown]
# Some people have low income but live in very expensive houses
